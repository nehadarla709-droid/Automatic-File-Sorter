# %%
import os,shutil

# %%
path = r"C:\Users\Neha\Downloads\\"

# %%
os.listdir(path)

# %%
os.path.exists(path + 'excel files')
# Out:
# True

# %%
folder_names = ['excel files','image files','document files']
for loop in range(0,3):
    if not os.path.exists(path + folder_names[loop]):
        print(path + folder_names[loop])
        os.makedirs(path + folder_names[loop])
file_name = os.listdir(path)
for file in file_name:
    if file.endswith(('.xlsx','.xls')) and not os.path.exists(path + 'excel files'+ file):
        shutil.move(path + file , path + 'excel files\\' + file)
    elif file.endswith(('.jpg','.png','.jpeg')) and not os.path.exists(path + 'image files'+ file):
        shutil.move(path + file , path + 'image files\\' + file)
    elif file.endswith(('.pdf','.docx','.pptx','.txt')) and not os.path.exists(path + 'document files'+ file):
        shutil.move(path + file , path + 'document files\\' + file)

# %%
#To run continuously for every 10 sec

# %%
import time
while True:
    time.sleep(10)

# %%
#full code

# %%
import os,shutil,time
path = r"C:\Users\Neha\Downloads\\"
folder_names = ['excel files','image files','document files']
for loop in range(0,3):
    if not os.path.exists(path + folder_names[loop]):
        print(path + folder_names[loop])
        os.makedirs(path + folder_names[loop])
while True:
    file_name = os.listdir(path)
    for file in file_name:
         if file.endswith(('.xlsx','.xls')) and not os.path.exists(path + 'excel files'+ file):
             shutil.move(path + file , path + 'excel files\\' + file)
         elif file.endswith(('.jpg','.png','.jpeg')) and not os.path.exists(path + 'image files'+ file):
             shutil.move(path + file , path + 'image files\\' + file)
         elif file.endswith(('.pdf','.docx','.pptx','.txt')) and not os.path.exists(path + 'document files'+ file):
             shutil.move(path + file , path + 'document files\\' + file)
time.sleep(10)

# %%
os.listdir(path)
